# %% [raw]
# Latent Dirichlet Allocation (LDA)

# %%
# !pip install pyLDAvis
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 2.8 MB/s eta 0:00:0000:0100:01
# ...
#   Obtaining dependency information for numexpr from https://files.pythonhosted.org/packages/56/ed/ee046f0cd9d9a01002f4c2efa5f78dcb9e4e7a078d88ea182a79e8ef1ce3/numexpr-2.8.5-cp310-cp310-macosx_11_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/24.0 MB 441.6 kB/s eta 0:00:38
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/maggiebreyer/Documents/Education/IronHack/Week_9/Final_project/fin_proj/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/Users/maggiebreyer/Documents/Education/IronHack/Week_9/Final_project/fin_proj/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
# ...
